# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('data/bank-additional-full.csv', sep = ';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
# Select only the object type columns
obj_cols = df.select_dtypes(include=['object']).columns

# Loop over each object type column and count the number of instances and unique instances of each category
for col in obj_cols:
    count = len(df[col].dropna())
    unique_count = df[col].nunique()
    counts = df[col].value_counts()
    print("Column:", col)
    print("Total count:", count)
    print("Total unique instances:", unique_count)
    print(counts)
    print('----------------')
# Out:
# Column: job
# Total count: 41188
# Total unique instances: 12
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64
# ----------------
# Column: marital
# Total count: 41188
# Total unique instances: 4
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64
# ----------------
# Column: education
# Total count: 41188
# Total unique instances: 8
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64
# ----------------
# Column: default
# Total count: 41188
# Total unique instances: 3
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64
# ----------------
# Column: housing
# Total count: 41188
# Total unique instances: 3
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64
# ----------------
# Column: loan
# Total count: 41188
# Total unique instances: 3
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64
# ----------------
# Column: contact
# Total count: 41188
# Total unique instances: 2
# cellular     26144
# telephone    15044
# Name: contact, dtype: int64
# ----------------
# Column: month
# Total count: 41188
# Total unique instances: 10
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: month, dtype: int64
# ----------------
# Column: day_of_week
# Total count: 41188
# Total unique instances: 5
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: day_of_week, dtype: int64
# ----------------
# Column: poutcome
# Total count: 41188
# Total unique instances: 3
# nonexistent    35563
# failure         4252
# success         1373
# Name: poutcome, dtype: int64
# ----------------
# Column: y
# Total count: 41188
# Total unique instances: 2
# no     36548
# yes     4640
# Name: y, dtype: int64
# ----------------

# %%
# Count the number of occurrences of each unique value in column X
value_counts = df['y'].value_counts()

# Create a bar chart of the counts
plt.bar(value_counts.index, value_counts.values)
plt.title('Counts of Y/N/Unknown in Column X')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Re-engeneering the 'default', 'housing', 'loan' columns

# %%
# Reload the data
df = pd.read_csv('data/bank-additional-full.csv', sep = ';')

# %%
# Define a dictionary to map the values
map_dict = {'yes': 1, 'no': 0, 'unknown': 2}

# Apply the mapping to 'default', 'housing' and 'loan' columns using the loc accessor
df.loc[:, ['default', 'housing', 'loan']] = df.loc[:, ['default', 'housing', 'loan']].applymap(map_dict.get)

# Print the updated dataframe
df
# Out:
#        age          job  marital            education  default  housing  loan  \
# 0       56    housemaid  married             basic.4y        0        0     0
# 1       57     services  married          high.school        2        0     0
# 2       37     services  married          high.school        0        1     0
# 3       40       admin.  married             basic.6y        0        0     0
# 4       56     services  married          high.school        0        0     1
# ...    ...          ...      ...                  ...      ...      ...   ...
# 41183   73      retired  married  professional.course        0        1     0
# 41184   46  blue-collar  married  professional.course        0        0     0
# 41185   56      retired  married    university.degree        0        1     0
# 41186   44   technician  married  professional.course        0        0     0
# 41187   74      retired  married  professional.course        0        1     0
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# ### Re-engeneering the 'job' column

# %%
# Define a dictionary to map the values
map_dict = {'admin.': 1, 'blue-collar': 2, 'technician': 3, 'services': 4 \
           , 'management': 5, 'retired': 6, 'entrepreneur': 7, 'self-employed': 8 \
           , 'housemaid': 9, 'unemployed': 10, 'student': 11, 'unknown': 12}

# Apply the mapping to 'job' column using the loc accessor
df.loc[:, ['job']] = df.loc[:, ['job']].applymap(map_dict.get)

# Print the updated dataframe
df
# Out:
#        age  job  marital            education  default  housing  loan  \
# 0       56    9  married             basic.4y        0        0     0
# 1       57    4  married          high.school        2        0     0
# 2       37    4  married          high.school        0        1     0
# 3       40    1  married             basic.6y        0        0     0
# 4       56    4  married          high.school        0        0     1
# ...    ...  ...      ...                  ...      ...      ...   ...
# 41183   73    6  married  professional.course        0        1     0
# 41184   46    2  married  professional.course        0        0     0
# 41185   56    6  married    university.degree        0        1     0
# 41186   44    3  married  professional.course        0        0     0
# 41187   74    6  married  professional.course        0        1     0
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# ### Re-engeneering the 'marital' column

# %%
# Define a dictionary to map the values
map_dict = {'married': 1, 'single': 2, 'divorced': 3, 'unknown': 4}

# Apply the mapping to 'marital' column using the loc accessor
df.loc[:, ['marital']] = df.loc[:, ['marital']].applymap(map_dict.get)

# Print the updated dataframe
df
# Out:
#        age  job  marital            education  default  housing  loan  \
# 0       56    9        1             basic.4y        0        0     0
# 1       57    4        1          high.school        2        0     0
# 2       37    4        1          high.school        0        1     0
# 3       40    1        1             basic.6y        0        0     0
# 4       56    4        1          high.school        0        0     1
# ...    ...  ...      ...                  ...      ...      ...   ...
# 41183   73    6        1  professional.course        0        1     0
# 41184   46    2        1  professional.course        0        0     0
# 41185   56    6        1    university.degree        0        1     0
# 41186   44    3        1  professional.course        0        0     0
# 41187   74    6        1  professional.course        0        1     0
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %% [markdown]
# ### Re-engeneering the 'education' column

# %%
# Define a dictionary to map the values
map_dict = {'university.degree': 1, 'high.school': 2, 'basic.9y': 3, \
            'professional.course': 4, 'basic.4y': 5, 'basic.6y': 6, \
            'unknown': 7, 'illiterate': 8}

# Apply the mapping to 'education' column using the loc accessor
df.loc[:, ['education']] = df.loc[:, ['education']].applymap(map_dict.get)

# Print the updated dataframe
df
# Out:
#        age  job  marital  education  default  housing  loan    contact month  \
# 0       56    9        1          5        0        0     0  telephone   may
# 1       57    4        1          2        2        0     0  telephone   may
# 2       37    4        1          2        0        1     0  telephone   may
# 3       40    1        1          6        0        0     0  telephone   may
# 4       56    4        1          2        0        0     1  telephone   may
# ...    ...  ...      ...        ...      ...      ...   ...        ...   ...
# 41183   73    6        1          4        0        1     0   cellular   nov
# 41184   46    2        1          4        0        0     0   cellular   nov
# 41185   56    6        1          1        0        1     0   cellular   nov
# 41186   44    3        1          4        0        0     0   cellular   nov
# 41187   74    6        1          4        0        1     0   cellular   nov
#
#       day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0             mon  ...         1    999         0  nonexistent          1.1
# 1             mon  ...         1    999         0  nonexistent          1.1
# 2             mon  ...         1    999         0  nonexistent          1.1
# 3             mon  ...         1    999         0  nonexistent          1.1
# 4             mon  ...         1    999         0  nonexistent          1.1
# ...           ...  ...       ...    ...       ...          ...          ...
# 41183         fri  ...         1    999         0  nonexistent         -1.1
# 41184         fri  ...         1    999         0  nonexistent         -1.1
# 41185         fri  ...         2    999         0  nonexistent         -1.1
# 41186         fri  ...         1    999         0  nonexistent         -1.1
# 41187         fri  ...         3    999         1      failure         -1.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 0              93.994          -36.4      4.857       5191.0   no
# 1              93.994          -36.4      4.857       5191.0   no
# 2              93.994          -36.4      4.857       5191.0   no
# 3              93.994          -36.4      4.857       5191.0   no
# 4              93.994          -36.4      4.857       5191.0   no
# ...               ...            ...        ...          ...  ...
# 41183          94.767          -50.8      1.028       4963.6  yes
# 41184          94.767          -50.8      1.028       4963.6   no
# 41185          94.767          -50.8      1.028       4963.6   no
# 41186          94.767          -50.8      1.028       4963.6  yes
# 41187          94.767          -50.8      1.028       4963.6   no
#
# [41188 rows x 21 columns]
